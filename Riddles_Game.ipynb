# %% [markdown]
# <a href="https://colab.research.google.com/github/Imran25git/Practice-projects/blob/My-Codes/Riddles_Game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("\t\t\t\tRiddles Game.")
print("LEVEL 1")
list_of_riddles1 = ["Which fish costs the most?","What gets smaller every time it takes a bath?","What five-letter word typed in all capital letters can be read the same upside down?","The more you take, the more you leave behind. What am I?","David's father has three sons: Snap, Crackle and _____?"]
answer_of_riddles1 = ["Goldfish", "Soap", "SWIMS", "Footsteps", "David"]
for i in range(len(list_of_riddles1)):
    print(list_of_riddles1[i])
    answer = input("Write answer here: ")
    if answer.strip().lower() == answer_of_riddles1[i].lower():
      print("⭐")
    else:
      print("❌")

print("\n")
print("LEVEL 2")
list_of_riddles2 = ["What is more useful when it is broken?","I am easy to lift, but hard to throw. What am I?","Where do you take a sick boat?","What kind of tree can you carry in your hand?","What is always in front of you, but can’t be seen?"]
answer_of_riddles2 = ["Egg", "Feather", "To the dock", "Palm", "The future"]
for i in range(len(list_of_riddles2)):
  print(list_of_riddles2[i])
  answer = input("Write answer here: ")
  if answer.strip().lower() == answer_of_riddles2[i].lower():
    print("⭐")
  else:
    print("❌")

print("\n")
print("LEVEL 3")
list_of_riddles3 = ["What goes up, but never comes down?","A cowboy rode into town on Friday. He stayed for three nights and rode out on Friday. How is this possible?","What has a neck but no head?","What is full of holes but still holds water?","How do you spell COW in thirteen letters?"]
answer_of_riddles3 = ["Age", "His horse's name is Friday", "Bottle", "Sponge", "See O Double You"]
for i in range(len(list_of_riddles3)):
  print(list_of_riddles3[i])
  answer = input("Write answer here: ")
  if answer.strip().lower() == answer_of_riddles3[i].lower():
    print("⭐")
  else:
    print("❌")

print("\n")
print("LEVEL 4")
list_of_riddles4 = ["If 2 is company and 3 is a crowd, what are 4 and 5?","Why is Europe like a frying pan?","What do the numbers 11, 69 and 88 all have in common?","Rachel goes to the supermarket and buys 10 tomatoes. Unfortunately, on the way back home, all but 9 get ruined. How many tomatoes are left in a good condition?","What is 3/7 chicken, 2/3 cat, and 2/4 goat?"]
answer_of_riddles4 = ["9", "Because it has Greece at the bottom", "They look the same upside down", "9", "Chicago"]
for i in range(len(list_of_riddles4)):
  print(list_of_riddles4[i])
  answer = input("Write answer here: ")
  if answer.strip().lower() == answer_of_riddles4[i].lower():
    print("⭐")
  else:
    print("❌")
print("\n")
print("LEVEL 5")
list_of_riddles5 = ["What has hands but cannot clap?","Paul's height is six feet, he's an assistant at a butcher's shop, and wears size 9 shoes. What does he weigh?","Poor people have it. Rich people need it. If you eat it you die. What is it?","What is the longest word in the dictionary?","What is at the end of a rainbow?"]
answer_of_riddles5 = ["Clock", "Meat", "Nothing", "Smiles", "W"]
for i in range(len(list_of_riddles5)):
  print(list_of_riddles5[i])
  answer = input("Write answer here: ")
  if answer.strip().lower() == answer_of_riddles5[i].lower():
    print("⭐")
  else:
    print("❌")

print("\t\t\t\tGame Endedf")
